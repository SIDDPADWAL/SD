# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#Lets load the dataset and sample some
column_names = ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat', 'medv']
df = pd.read_csv('BostonHousing.csv')

# %%
# Dimension of the dataset
print(np.shape(df))
# Out:
# (506, 14)

# %%
# Let's summarize the data to see the distribution of data
print(df.describe())
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset
df = pd.read_csv("BostonHousing.csv")

fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()

for k, v in df.items():
    sns.boxplot(y=df[k], ax=axs[index])
    axs[index].set_title(k)
    index += 1

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
plt.show()

# %%
for k, v in df.items():
        q1 = v.quantile(0.25)
        q3 = v.quantile(0.75)
        irq = q3 - q1
        v_col = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
        perc = np.shape(v_col)[0] * 100.0 / np.shape(df)[0]
        print("Column %s outliers = %.2f%%" % (k, perc))
# Out:
# Column crim outliers = 13.04%
# Column zn outliers = 13.44%
# Column indus outliers = 0.00%
# Column chas outliers = 100.00%
# Column nox outliers = 0.00%
# Column rm outliers = 5.93%
# Column age outliers = 0.00%
# Column dis outliers = 0.99%
# Column rad outliers = 0.00%
# Column tax outliers = 0.00%
# Column ptratio outliers = 2.96%
# Column b outliers = 15.22%
# Column lstat outliers = 1.38%
# Column medv outliers = 7.91%

# %%
df = df[~(df['medv'] >= 35.0)]
print(np.shape(df))
# Out:
# (458, 14)

# %%
#Looking at the data with names and target variable
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 5  394.12   5.21  28.7

# %%
#Shape of the data
print(df.shape)
# Out:
# (458, 14)

# %%
#Checking the null values in the dataset
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
#Checking the statistics of the data
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  458.000000  458.000000  458.000000  458.000000  458.000000  458.000000
# mean     3.880713   10.180131   11.588166    0.058952    0.558875    6.156945
# std      8.973996   21.950057    6.756057    0.235792    0.117724    0.563489
# min      0.006320    0.000000    0.740000    0.000000    0.385000    3.561000
# 25%      0.084020    0.000000    5.860000    0.000000    0.453000    5.871250
# 50%      0.256510    0.000000    9.900000    0.000000    0.538000    6.152000
# 75%      4.082653    0.000000   18.100000    0.000000    0.624000    6.481750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  458.000000  458.000000  458.000000  458.000000  458.000000  458.000000
# mean    69.170524    3.807797    9.842795  417.893013   18.676201  353.521965
# std     28.008853    2.125004    8.884462  168.736868    2.027875   95.363794
# min      2.900000    1.137000    1.000000  187.000000   12.600000    0.320000
# 25%     45.725000    2.100175    4.000000  287.000000   17.600000  373.105000
# 50%     78.400000    3.199200    5.000000  345.000000   19.200000  391.880000
# 75%     94.300000    5.214600   24.000000  666.000000   20.200000  396.397500
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  458.000000  458.000000
# mean    13.490699   20.320087
# std      6.967358    6.185151
# min      1.980000    5.000000
# 25%      7.927500   16.200000
# 50%     12.370000   20.400000
# 75%     17.302500   23.800000
# max     37.970000   34.900000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     458 non-null    float64
#  1   zn       458 non-null    float64
#  2   indus    458 non-null    float64
#  3   chas     458 non-null    int64
#  4   nox      458 non-null    float64
#  5   rm       458 non-null    float64
#  6   age      458 non-null    float64
#  7   dis      458 non-null    float64
#  8   rad      458 non-null    int64
#  9   tax      458 non-null    int64
#  10  ptratio  458 non-null    float64
#  11  b        458 non-null    float64
#  12  lstat    458 non-null    float64
#  13  medv     458 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 53.7 KB

# %%
#checking the distribution of the target variable
import seaborn as sns
sns.histplot(df.medv , kde = True)
# Out:
# <Axes: xlabel='medv', ylabel='Count'>

# %%
#Distribution using box plot
sns.boxplot(df.medv)
# Out:
# <Axes: ylabel='medv'>

# %%
#checking Correlation of the data
correlation = df.corr()
correlation.loc['medv']
# Out:
# crim      -0.509111
# zn         0.432791
# indus     -0.598380
# chas       0.098362
# nox       -0.584249
# rm         0.540151
# age       -0.571890
# dis        0.461164
# rad       -0.515860
# tax       -0.587285
# ptratio   -0.471471
# b          0.404020
# lstat     -0.780531
# medv       1.000000
# Name: medv, dtype: float64

# %%
# plotting the heatmap
import matplotlib.pyplot as plt
fig,axes = plt.subplots(figsize=(15,12))
sns.heatmap(correlation,square = True,annot = True)
# Out:
# <Axes: >

# %%
# Checking the scatter plot with the most correlated features
plt.figure(figsize = (20,5))
features = ['lstat','rm','ptratio']
for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = df[col]
    y = df.medv
    plt.scatter(x, y, marker='o')
    plt.title("Variation in House prices")
    plt.xlabel(col)
    plt.ylabel('"House prices in $1000"')

# %%
#X = data[['LSTAT','RM','PTRATIO']]
X = df.iloc[:,:-1]
y= df.medv

# %%
# Splitting the data into train and test for building the model
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 4)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
#Fitting the model
regressor.fit(X_train,y_train)

# %%
#Prediction on the test dataset
y_pred = regressor.predict(X_test)

# %%
# Predicting RMSE the Test set results
from sklearn.metrics import mean_squared_error
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))
print(rmse)
# Out:
# 3.0613157648526625

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.7443761652148504

# %%
#Scaling the dataset
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Creating the neural network model
import keras
from keras.layers import Dense, Activation,Dropout
from keras.models import Sequential

model = Sequential()

model.add(Dense(128,activation  = 'relu',input_dim =13))
model.add(Dense(64,activation  = 'relu'))
model.add(Dense(32,activation  = 'relu'))
model.add(Dense(16,activation  = 'relu'))
model.add(Dense(1))
model.compile(optimizer = 'adam',loss = 'mean_squared_error')

# %%
model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 430.2274
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 361.9081
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 232.6404
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 84.6222
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.9141
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.1808
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.8323
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.1411
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4093
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.9231
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7671
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.0918
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3616
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7547
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3620
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9608
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5959
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3840
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0836
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9129
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8452
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5897
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5565
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5120
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2350
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0234
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9368
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8109
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7891
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7872
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5124
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4223
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3977
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2717
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1657
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0966
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0404
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9303
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8215
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7960
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6883
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7166
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5434
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5110
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5508
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5763
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1929
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0900
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1411
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0021
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0052
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8475
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8542
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9450
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6877
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6651
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7714
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6629
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4980
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4232
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6082
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2741
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5223
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3844
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4116
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2802
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1924
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2193
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1288
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0027
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9702
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9758
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9299
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0240
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1324
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0982
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9178
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7853
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7760
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8076
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7073
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7558
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7807
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6524
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8350
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5864
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5764
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7004
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4665
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5343
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4889
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3409
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5471
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4143
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3836
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2686
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2945
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2201
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1846
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2435

# %%
y_pred = model.predict(X_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.8353268027084955

# %%
# Predicting RMSE the Test set results
from sklearn.metrics import mean_squared_error
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))
print(rmse)
# Out:
# 2.457077834018194
